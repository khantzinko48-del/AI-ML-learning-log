# %% [markdown]
# <a href="https://colab.research.google.com/github/khantzinko48-del/AI-ML-learning-log/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np . array ([[1,2,3,],[4,5,6]])
print(data.shape)
# Out:
# (2, 3)

# %%
import numpy as np
A = np.array ([1, 2, 3])
B = np.array ([4, 5, 6])
print ("A + B =", A + B)
print("A * 2 =", A * 2)
# Out:
# A + B = [5 7 9]
# A * 2 = [2 4 6]
